# %% [markdown]
# <a href="https://colab.research.google.com/github/Diksha57-git/Pythonprograms/blob/main/Basics.ipynb" target="_blank"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open this notebook in Colaboratory"/></a>

# %% [markdown]
# ######**Author: Diksha Tanwar**
# ######Date: 7-02-26
# ######Enroll Num: 250242
# ######Course: BCA
# ######Course Code: 23.136

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
a = 15
b = 12

# Adding two numbers
c = a + b
print(c)
# Out:
# 27

# %%
num = int(input("Enter a number: "))
if (num % 2) == 0:
   print("num is Even")
else:
   print("num is Odd")
# Out:
# Enter a number: 5
# num is Odd

# %%
first_name = "John"
last_name = "Doe"

# Concatenation
full_name = first_name + " " + last_name
print(full_name)

# Length of the string
length = len(full_name)
print(f"Length of full name: {length}") # f-string formatting
# Out:
# John Doe
# Length of full name: 8

# %%
age = int(input("Enter your age: "))

if age >= 18:
    print("You are eligible to vote.")
else:
    print("You are not eligible to vote.")
# Out:
# Enter your age: 56
# You are eligible to vote.

# %%
fruits = ["apple", "banana", "cherry"]
for fruit in fruits:
    print(fruit)
# Out:
# apple
# banana
# cherry

# %%
word = "Python"
for character in word:
    print(character)
# Out:
# P
# y
# t
# h
# o
# n
