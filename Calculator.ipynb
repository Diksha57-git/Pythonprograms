# %% [markdown]
# <a href="https://colab.research.google.com/github/Diksha57-git/Pythonprograms/blob/main/Calculator.ipynb" target="_blank"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open this notebook in Colaboratory"/></a>

# %% [markdown]
# ######**Author: Diksha Tanwar**
# ######Date: 7-01-26
# ######Enroll Num: 250242
# ######Course: BCA
# ######Course Code: 23.136

# %%
import numpy
a=5
b=7
c=a+b
print("First num:",a)
print("Second num:",b)
print("Addition:",c)
print("Substraction:",(a-b))
print("Division:",(a/b))
print("Multiplication:",(a*b))
print("modulas:",(a%b))
# Out:
# First num: 5
# Second num: 7
# Addition: 12
# Substraction: -2
# Division: 0.7142857142857143
# Multiplication: 35
# modulas: 5
