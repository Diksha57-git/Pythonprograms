# %%
a=5
b=7
c=a+b
print(c)
# Out:
# 12

# %%
print("5"+"6")
# Out:
# 56

# %%
print(int("5")+int("6"))
# Out:
# 11

# %%
a=str(5)
b="Hello"
print(a+b)
# Out:
# 5Hello

# %%
a=int(input("Enter value of a: "))
b=int(input("Enter value of b: "))
print(a+b)
# Out:
# Enter value of a: 34
# Enter value of b: 34
# 68
