# %% [markdown]
# <a href="https://colab.research.google.com/github/Diksha57-git/Pythonprograms/blob/main/Largest&Smallest.ipynb" target="_blank"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open this notebook in Colaboratory"/></a>

# %% [markdown]
# ######**Author: Diksha Tanwar**
# ######Date: 10-01-26
# ######Enroll Num: 250242
# ######Course: BCA
# ######Course Code: 23.136

# %% [markdown]
# * PURPOSE OF THIS PROGRAM
# * To Find the largest num
# * To Find the Smallest Number

# %%
#Find the largest and Smallest Number
a=int(input("Enter the value of first Number"))
b=int(input("Enter the value of second Number"))
c=int(input("Enter the value of third Number"))
#For largest
if(a>b and a>c):
  print(a,"is Largest")
elif(b>a and b>c):
  print(b,"is Largest")
else:
  print(c,"is Largest")

# For smallest
if(a<b and a<c):
  print(a,"is Smallest")
elif(b<a and b<c):
  print(b,"is Smallest")
else:
  print(c,"is Smallest")
# Out:
# Enter the value of first Number888
# Enter the value of second Number8888
# Enter the value of third Number8888
# 8888 is Largest
# 888 is Smallest
